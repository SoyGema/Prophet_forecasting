# %% [markdown]
# ### Asteroid Forecasting

# %%
import pandas as pd
import numpy as np
from fbprophet import Prophet
import matplotlib

# %%
df = pd.read_csv('/Data')
df['ds'] = pd.to_datetime(df['ds'], format='%Y-%m-%d')

# %%
df.head()
# Out:
#           ds        y
# 0 2017-06-02  0.11109
# 1 2017-06-02  0.02590
# 2 2017-06-01  0.05177
# 3 2017-06-01  0.14338
# 4 2017-05-30  0.05711

# %%
model = Prophet()
model.fit(df);

# %%
future = model.make_future_dataframe(periods=30)
future
# Out:
#              ds
# 0    1932-04-24
# 1    1936-02-12
# 2    1937-10-28
# 3    1947-12-12
# 4    1948-03-07
# 5    1948-07-17
# 6    1949-06-27
# 7    1950-02-22
# 8    1951-09-14
# 9    1959-06-05
# 10   1960-09-24
# 11   1960-09-24
# 12   1960-10-22
# 13   1971-03-24
# 14   1971-10-26
# 15   1972-12-05
# 16   1973-03-06
# 17   1973-07-04
# 18   1974-06-26
# 19   1975-12-27
# 20   1976-01-07
# 21   1976-10-22
# 22   1976-11-19
# 23   1977-04-17
# 24   1977-04-24
# 25   1978-02-08
# 26   1978-09-10
# 27   1978-09-27
# 28   1979-11-15
# 29   1979-12-11
# ...         ...
# 9289 2017-06-03
# 9290 2017-06-04
# 9291 2017-06-05
# 9292 2017-06-06
# 9293 2017-06-07
# 9294 2017-06-08
# 9295 2017-06-09
# 9296 2017-06-10
# 9297 2017-06-11
# 9298 2017-06-12
# 9299 2017-06-13
# 9300 2017-06-14
# 9301 2017-06-15
# 9302 2017-06-16
# 9303 2017-06-17
# 9304 2017-06-18
# 9305 2017-06-19
# 9306 2017-06-20
# 9307 2017-06-21
# 9308 2017-06-22
# 9309 2017-06-23
# 9310 2017-06-24
# 9311 2017-06-25
# 9312 2017-06-26
# 9313 2017-06-27
# 9314 2017-06-28
# 9315 2017-06-29
# 9316 2017-06-30
# 9317 2017-07-01
# 9318 2017-07-02
#
# [9319 rows x 1 columns]

# %%
forecast = model.predict(future)
forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail()
# Out:
#              ds      yhat  yhat_lower  yhat_upper
# 9314 2017-06-28  0.057697   -0.035364    0.157855
# 9315 2017-06-29  0.056387   -0.041152    0.153978
# 9316 2017-06-30  0.058370   -0.036839    0.146536
# 9317 2017-07-01  0.057830   -0.035381    0.159894
# 9318 2017-07-02  0.057357   -0.041045    0.165804

# %%
# %matplotlib inline
c = model.plot(forecast);

# %%
model.plot_components(forecast);
